# %%
import pandas as pd

# %%
data=pd.read_csv('./internshipData/sportsdata.csv',low_memory=False)
df=pd.DataFrame(data)
df
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 362442  2017-01-01  2017010102     20    4   1.0  00:22          1      22.0
# 362443  2017-01-01  2017010102     20    4   NaN  00:13          1      13.0
# 362444  2017-01-01  2017010102     21    4   NaN  00:13          1      13.0
# 362445  2017-01-01  2017010102     21    4   1.0  00:12          1      12.0
# 362446  2017-01-01  2017010102     21    4   NaN  00:00          0       0.0
#
# ...

# %%
df.iloc[:,16:35]  #printing ranges of rows x columns [start index of row : end index of row,start index of column : end index of column]
# Out:
#        posteam DefensiveTeam  \
# 0          PIT           TEN
# 1          PIT           TEN
# 2          PIT           TEN
# 3          PIT           TEN
# 4          PIT           TEN
# ...        ...           ...
# 362442     DET            GB
# 362443     DET            GB
# 362444      GB           DET
# 362445      GB           DET
# 362446      GB           DET
#
#                                                      desc  PlayAttempted  \
# 0       R.Bironas kicks 67 yards from TEN 30 to PIT 3....              1
# 1       (14:53) B.Roethlisberger pass short left to H....              1
# 2       (14:16) W.Parker right end to PIT 44 for -3 ya...              1
# 3       (13:35) (Shotgun) B.Roethlisberger pass incomp...              1
# 4       (13:27) (Punt formation) D.Sepulveda punts 54 ...              1
# ...                                                   ...            ...
# 362442  (:22) (Shotgun) M.Stafford pass deep middle to...              1
# ...
